# %% [markdown]
# # Parameterisation of granulometric data for spray models

# %% [markdown]
# The objective if to build the (v,D) distribution used in spray and estimae the popdrops and popdrops outputs
#
# - TODO : the nozzles used at Boigneville was XR 110-015 (To check with Benjamin). This means 110 degrees angular osprayin with a nozzle of 15 mm diameter
#
# - Data measured in the lab are for XR 080-015, XR 110-020, XR 110-030 and XR 110-040, at 25 cm distance => Misssing the one used in Boigneville (may be available 2014 from Eric). Currently est default choice is XR 110-020
#
# - on the boom the inter-distance between nozzles in 50 cm
#
# - to get estimate of distribution under the boom we hypothetise a fan-like sprayiong in the distance-range 0-50 cm and then vertical = Data are to be processed to get extrapolation at 50cm and estimates of overlaps of distribution
#
# - after popdrops is used to get estimates of splash/roll/impacts for the different volume applied at the dfferent dates

# %%
from IPython.display import Image

# %%
im = Image('spraying.jpg')
im
