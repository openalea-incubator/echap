# %% [markdown]
# # Compare ADEL simulation vs. field data for leaf by leaf properties

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from alinea.echap.evaluation_leaf_properties import *

# %% [markdown]
# ## Mercia

# %% [markdown]
# TODO : Trier et mettre en forme data dans disque Image-DB

# %% [markdown]
# ## Rht3

# %% [markdown]
# ## Tremie12

# %%
variety = 'Tremie12'
nplants=30

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = variety, nplants = nplants, leaves = range(1, 14),
                              variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [200., 1700.], ylims = [0., 25.])

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = variety, nplants = 15, leaves = range(1, 14),
                              variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [200., 1700.], ylims = [0., 25.])

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = 'Tremie12', nplants = 15, leaves = range(1, 14),
                              variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [200., 1700.], ylims = [0., 25.])

# %% [markdown]
# TODO : METTRE TOUTES LES FEUILLES

# %% [markdown]
# TODO : regarder plutot en %senescent parce que plus de points
#
# TODO : tracer nec apicale "symptom_tagged" only
# TODO : comparer 2 ci-dessus ??

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged(variety = 'Tremie12', nplants = nplants, variable = 'necro_tot', xaxis = 'HS', 
                    xlims = [6., 20.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves by final leaf number (FNL)
compare_sim_tagged_by_fnl(variety = 'Tremie12', nplants = nplants, variable = 'necro_tot', xaxis = 'degree_days', 
                        error_bars = False, xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_symptom_tagged(variety = 'Tremie12', nplants = nplants, variable = 'necro', xaxis = 'degree_days', 
                            xlims = [1000., 2200.], ylims = [0., 100.])

# %% [markdown]
# Recuperer senescence apicale uniquement

# %%
# Compare average simulated leaf area with data from scanned leaves
compare_sim_scan(variety = 'Tremie12', nplants = nplants, variable = 'area', xaxis = 'degree_days',
                 exclude_stat = None, xlims = [500., 1600.], ylims = [0, 30])

# %% [markdown]
# Normal baisse des points 8, 9, 10 ?

# %% [markdown]
# ## Tremie13

# %%
variety = 'Tremie13'
nplants = 30

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = variety, nplants = nplants, leaves = range(1, 14),
                              variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [200., 1700.], ylims = [0., 25.])

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = 'Tremie13', nplants = 15, leaves = range(1, 14),
                              variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [200., 1700.], ylims = [0., 25.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged(variety = variety, nplants = nplants, variable = 'necro_tot', xaxis = 'degree_days', 
                    xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged_by_fnl(variety = variety, nplants = nplants, variable = 'necro_tot', xaxis = 'degree_days', 
                        error_bars = False, xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_symptom_tagged(variety = variety, nplants = nplants, variable = 'necro', xaxis = 'degree_days', 
                            xlims = [1000., 2200.], ylims = [0., 100.])

# %% [markdown]
# ### Tremie12 With grouped leaves

# %% [markdown]
# /!\ ATTENTION : Premier point a moins de feuilles dans les données que dans la simu...

# %%
variety = 'Tremie12'
nplants = 10

# %%
# Compare sum of lengths of leaves on main stems
compare_splant(variety = variety, nplants=nplants, variable = 'length', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of lengths of leaves on tillers
compare_splant(variety = variety, nplants=nplants, variable = 'length', xaxis = 'degree_days', axes = 'tillers')

# %%
# Compare sum of areas of leaves on main stems
compare_splant(variety = variety, nplants=nplants, variable = 'area', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of areas of leaves on tillers
compare_splant(variety = variety, nplants=nplants, variable = 'area', xaxis = 'degree_days', axes = 'tillers')
