# %% [markdown]
# # Compare ADEL simulation vs. field data for LAI, cover fraction, intercepted radiation

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from alinea.echap.evaluation_canopy_properties import *

# %%
test_architecture_canopy(nplants = 30, fig_size = (15, 15))
from pylab import savefig
#savefig('canopy_eval.png')

# %% [markdown]
# Tremie 12 et 13 ok: verifier criteres feuilles
#
# Mercia pas assez rapide --> TODO : remettre mouche mesurée, partir + tôt ?
#
# Rht3 "c'est le pire" --> TODO : donnees pour le d (où sont-elles ?), travail spécifique sur la geometrie (ecartement des talles)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
# Geoaxe:
#
# *rythme inclinaison des talles 15 (varie entre 10 et 20)
#
# *rht3 angle d'inclinaison max jusqu'à 75° et il ne se redresse qu'un peu (botte de 13), angle d'inclinaison des autres = 60°
#
# *rht3 fixer "face_up = True"
#
# *dmin = 1h.5; dmax = 7 mais faire une variation sur le rang, mettons 4cm
#
# + en plus on peut jouer sur azimut des feuilles pour mieu repartir les talles
# + à la fin on peut jouer sur paramètre de disparition de feuilles et de talles
# + vérifier la valeur de f_sen_shrink

# %% [markdown]
# ####  TO DO : Tracer Axe density simulee / axe density demande (et points ?)
