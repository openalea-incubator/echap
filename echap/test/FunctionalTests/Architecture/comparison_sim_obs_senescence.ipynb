# %% [markdown]
# # Comparison of apical senescence measured in septoria data and apical senescence simulated with Adel

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
from alinea.echap.disease.alep_septo_evaluation import *
data_2012_obs, weather_2012 = data_reader(year = 2012, variety = 'Tremie12', from_file = 'reference',
                                  wetness_duration_min = 10., temp_min = 0., temp_max = 25.)
data_2012_sim = get_data_sim(filename = 'D:/openaleapkg/alep/example/tremie/recorder_2012_30pl_7sect_frac2e-4.pckl', 
                             weather = weather_2012)
data_2012_sim['necro'] = 100*data_2012_sim['leaf_senesced_area']/data_2012_sim['leaf_area'].replace({ 0 : np.inf })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-074934d2bb75> in <module>()
#       9                                   wetness_duration_min = 10., temp_min = 0., temp_max = 25.)
#      10 data_2012_sim = get_data_sim(filename = 'D:/openaleapkg/alep/example/tremie/recorder_2012_30pl_7sect_frac2e-4.pckl',
# ---> 11                              weather = weather_2012)
#      12 data_2012_sim['necro'] = 100*data_2012_sim['leaf_senesced_area']/data_2012_sim['leaf_area'].replace({ 0 : np.inf })
#
# d:\openaleapkg\echap\src\alinea\echap\disease\alep_septo_evaluation.pyc in get_data_sim(filename, weather, adel, skipna)
#      98                  weather = None, adel =None, skipna = True):
#      99     recorder = get_recorder(filename)
# --> 100     return recorder_to_dataframe(recorder, weather = weather, adel = adel, skipna = skipna)
#     101
# ...

# %%
data_2012_sim['necro'] = 100*data_2012_sim['leaf_senesced_area']/data_2012_sim['leaf_area'].replace({ 0 : np.inf })

# %%
data_2013_obs, weather_2013 = data_reader(year = 2013, variety = 'Tremie13', from_file = 'reference',
                                  wetness_duration_min = 10., temp_min = 0., temp_max = 25.)
data_2013_sim = get_data_sim(filename = 'D:/openaleapkg/alep/example/tremie/recorder_stabtest_tremie13_1pl.pckl', 
                             weather = weather_2013)
data_2013_sim['necro'] = 100*data_2013_sim['leaf_senesced_area']/data_2013_sim['leaf_area'].replace({ 0 : np.inf })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4b427d9f6f9c> in <module>()
#       2                                   wetness_duration_min = 10., temp_min = 0., temp_max = 25.)
#       3 data_2013_sim = get_data_sim(filename = 'D:/openaleapkg/alep/example/tremie/recorder_stabtest_tremie13_1pl.pckl',
# ----> 4                              weather = weather_2013)
#       5 data_2013_sim['necro'] = 100*data_2013_sim['leaf_senesced_area']/data_2013_sim['leaf_area'].replace({ 0 : np.inf })
#
# d:\openaleapkg\echap\src\alinea\echap\disease\alep_septo_evaluation.pyc in get_data_sim(filename, weather, adel, skipna)
#      94                  weather = None, adel =None, skipna = True):
#      95     recorder = get_recorder(filename)
# ---> 96     return recorder_to_dataframe(recorder, weather = weather, adel = adel, skipna = skipna)
#      97
# ...

# %%
plot_by_leaf_sample(data_2012_sim, weather_2012, leaf = 5, variable = 'necro', xaxis = 'degree_days')

# %%
plot_by_leaf(data_2012_sim, weather_2012, leaves = range(1, 14), 
             variable = 'leaf_senesced_area', xaxis = 'degree_days',
             ylims = [0, 30], marker = '', with_brewer = False, pointer = False)

# %%
plot_by_leaf(data_2012_sim, weather_2012, leaves = range(1, 14), 
             variable = 'leaf_green_area', xaxis = 'degree_days',
             ylims = [0, 25], xlims = [0, 2200], marker = '', with_brewer = False, pointer = False)

# %%
data_plant, weather = data_reader(year = 2012, variety = 'Tremie12', from_file = 'senescence')

# %%
data_2012_sim_g = group_by_fnl(data_2012_sim)
data_2012_plant_g = group_by_fnl(data_plant)

# %%
data_2012_obs_g = group_by_fnl(data_2012_obs)

# %%
compare_plot_by_leaf_two_datasets(data_2012_sim_g[12], data_2012_obs_g[12], weather_2012,
                                  variable = 'necro', xaxis = 'degree_days', markers = ['', 'd'],
                                  labels = ['sim', 'obs'], xlims = [1000, 2400], minimum_sample_size = 0)

# %%
compare_plot_by_leaf_two_datasets(data_2012_sim_g[13], data_2012_obs_g[13], weather_2012,
                                  variable = 'necro', xaxis = 'age_leaf_lig', markers = ['', 'd'],
                                  labels = ['sim', 'obs'], xlims = [0, 1000], minimum_sample_size = 0)

# %%
compare_plot_by_leaf_two_datasets(data_2012_sim_g[13], data_2012_obs_g[13], weather_2012,
                                  variable = 'necro', markers = ['', 'd'],
                                  labels = ['sim', 'obs'], xlims = [1000, 2200], minimum_sample_size = 0)

# %%
compare_plot_by_leaf_two_datasets(data_2013_sim, data_2013_obs, weather_2013,
                                  variable = 'necro', markers = ['', 'd'],
                                  labels = ['sim', 'obs'], xlims = [1000, 2200], minimum_sample_size = 0)

# %%
compare_plot_by_leaf_two_datasets(data_2012_sim, data_2012_obs, weather_2012, leaves = [3],
                                  variable = 'necro', xaxis = 'age_leaf', markers = ['', 'd'],
                                  labels = ['sim', 'obs'], xlims = [0, 1000], error_bars = True)
# Out:
# C:\Python27\lib\site-packages\scikits.bootstrap-0.3.2-py2.7.egg\scikits\bootstrap\bootstrap.py:202: InstabilityWarning: Some values used top 10 low/high samples; results may be unstable.

# %%
compare_confidence_and_boxplot_two_datasets(data_2012_sim, data_2012_obs, weather_2012, 
                                            variable = 'necro', xaxis = 'age_leaf',
                                            leaves=range(1,7), fig_size=(15, 10),
                                            display_error_margin = [False, True],
                                            display_box = [False, True],
                                            labels = ['sim', 'obs'], xlims = [0,1300])

# %%
warnings.filterwarnings('ignore')
compare_confidence_and_boxplot_two_datasets(data_2013_sim, data_2013_obs, weather_2013, 
                                            variable = 'necro', xaxis = 'age_leaf',
                                            leaves=range(1,5), fig_size=(15, 10),
                                            display_error_margin = [False, True],
                                            display_box = [False, True],
                                            labels = ['sim', 'obs'], xlims = [0,1300])
