# %% [markdown]
# # Compare ADEL simulation vs. field data for leaf by leaf properties

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from evaluation_leaf_properties import *

# %% [markdown]
# ## Mercia

# %% [markdown]
# ## Rht3

# %% [markdown]
# ## Tremie12

# %%
variety = 'Tremie12'

# %% [markdown]
# ### With grouped leaves

# %%
# Compare sum of lengths of leaves on main stems
compare_splant(variety = variety, variable = 'length', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of lengths of leaves on tillers
compare_splant(variety = variety, variable = 'length', xaxis = 'degree_days', axes = 'tillers')

# %%
# Compare sum of areas of leaves on main stems
compare_splant(variety = variety, variable = 'area', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of areas of leaves on tillers
compare_splant(variety = variety, variable = 'area', xaxis = 'degree_days', axes = 'tillers')

# %% [markdown]
# ### Leaf by leaf comparison

# %%
# Compare average simulated leaf length with data from scanned (a) and tagged (b) leaves
compare_sim_scan_tagged(variety = variety, variable = 'length', xaxis = 'degree_days', 
                        exclude_stat = None, xlims = [500., 1700.], ylims = [0., 25.])

# %%
# Compare average simulated leaf senesced length with data from scanned (a) and tagged (b) leaves
compare_sim_scan_tagged(variety = variety, variable = 'senesced_length', xaxis = 'degree_days', 
                        exclude_stat = None, xlims = [0., 2000.], ylims = [0., 25.])

# %%
# Compare average simulated leaf area with data from scanned leaves
compare_sim_scan(variety = variety, variable = 'area', xaxis = 'degree_days', exclude_stat = None)

# %% [markdown]
# Normal baisse des points 8, 9, 10 ?

# %%
# Compare average simulated leaf senesced area with data from scanned leaves
compare_sim_scan(variety = variety, variable = 'senesced_area', xaxis = 'degree_days', exclude_stat = None)

# %% [markdown]
# ## Tremie13
