# %% [markdown]
# # Compare ADEL simulation vs. field data for leaf by leaf properties

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from alinea.echap.evaluation_leaf_properties import *

# %% [markdown]
# ## Mercia

# %% [markdown]
# TODO : Trier et mettre en forme data dans disque Image-DB

# %% [markdown]
# ## Rht3

# %% [markdown]
# ## Tremie12

# %%
variety = 'Tremie12'

# %%
# Compare average simulated leaf length with data from scanned (a) and archi tagged (b) leaves
compare_sim_scan_archi_tagged(variety = variety, variable = 'length', xaxis = 'degree_days', 
                            exclude_stat = None, xlims = [500., 1700.], ylims = [0., 25.])

# %% [markdown]
# TODO : rapatrier donnees "symptom tagged"
#
# TODO : regarder plutot en %senescent parce que plus de points
#
# TODO : tracer par NFF
#
# TODO : tracer nec tot "archi_tagged" & "symptom_tagged" (points vide pour "archi_tagged", points plein pour "symptom_tagged")
# TODO : tracer nec apicale "symptom_tagged" only
# TODO : comparer 2 ci-dessus ??

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged(variety = 'Tremie12', variable = 'necro_tot', xaxis = 'degree_days', 
                    xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged_by_fnl(variety = 'Tremie12', variable = 'necro_tot', xaxis = 'degree_days', 
                        error_bars = False, xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_symptom_tagged(variety = 'Tremie12', variable = 'necro', xaxis = 'degree_days', 
                            xlims = [1000., 2200.], ylims = [0., 100.])

# %% [markdown]
# Recuperer senescence apicale uniquement

# %%
# Compare average simulated leaf area with data from scanned leaves
compare_sim_scan(variety = 'Tremie12', variable = 'area', xaxis = 'degree_days',
                 exclude_stat = None, xlims = [500., 1600.], ylims = [0, 30])

# %% [markdown]
# Normal baisse des points 8, 9, 10 ?

# %% [markdown]
# ## Tremie13

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged(variety = 'Tremie13', variable = 'necro_tot', xaxis = 'degree_days', 
                    xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_tagged_by_fnl(variety = 'Tremie13', variable = 'necro_tot', xaxis = 'degree_days', 
                        error_bars = False, xlims = [1000., 2200.], ylims = [0., 100.])

# %%
# Compare average simulated leaf senescence with data from symptom tagged leaves
compare_sim_symptom_tagged(variety = 'Tremie13', variable = 'necro', xaxis = 'degree_days', 
                            xlims = [1000., 2200.], ylims = [0., 100.])

# %% [markdown]
# ### Tremie12 With grouped leaves

# %%
# Compare sum of lengths of leaves on main stems
compare_splant(variety = variety, variable = 'length', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of lengths of leaves on tillers
compare_splant(variety = variety, variable = 'length', xaxis = 'degree_days', axes = 'tillers')

# %%
# Compare sum of areas of leaves on main stems
compare_splant(variety = variety, variable = 'area', xaxis = 'degree_days', axes = 'MS')

# %%
# Compare sum of areas of leaves on tillers
compare_splant(variety = variety, variable = 'area', xaxis = 'degree_days', axes = 'tillers')
