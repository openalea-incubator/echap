# %% [markdown]
# # Comparative analysis of septoria measurements on Mercia and Rht3 wheat from Grignon in 2011

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
wetness_duration_min = 10.
temp_min = 0.
temp_max = 25.
data_mercia, weather, adel_mercia = data_reader(year = 2011, variety = 'Mercia', from_file = 'control',
                                  wetness_duration_min = wetness_duration_min, temp_min = temp_min, temp_max = temp_max)
data_rht3, weather, adel_rht3 = data_reader(year = 2011, variety = 'Rht3', from_file = 'control',
                                  wetness_duration_min = wetness_duration_min, temp_min = temp_min, temp_max = temp_max)

# %% [markdown]
# ## Contingency

# %%
compare_contingency_2011(data_mercia, data_rht3, weather)
# Out:
#                        Mercia                      / Rht3                      \
#                             1   2   3   4   5   6  /    1   2   3   4   5   6
# Date       Degree days
# 2011-04-18 1127             -   -   -   -  36  36  /    -   -   -   -  36  36
# 2011-05-25 1690            90  90  90  90   -   -  /   90  90  90  86   -   -
# 2011-06-08 1921            90  90  90  45   -   -  /   90  90  90  21   -   -
#
#                             /
#                          7  /
# Date       Degree days
# 2011-04-18 1127         36  /
# 2011-05-25 1690          -  /
# 2011-06-08 1921          -  /

# %% [markdown]
# ## Mean data by leaf

# %%
# Show mean value
save_comparison_table_2011(data_mercia, data_rht3, weather, num_leaves = range(1,7))
# Out:
#                           Mercia                                           \
#                                1          2         3         4         5
# Date       Degree days
# 2011-04-18 1127              NaN        NaN       NaN       NaN  0.027778
# 2011-05-25 1690         0.177778   2.522222  6.066667  2.588889       NaN
# 2011-06-08 1921         0.311111  10.922222  9.277778  0.000000       NaN
#
#                                   /      Rht3                                  \
#                                6  /         1          2          3         4
# Date       Degree days
# 2011-04-18 1127         0.527778  /       NaN        NaN        NaN       NaN
# 2011-05-25 1690              NaN  /  0.844444  13.644444  28.166667  5.837209
# 2011-06-08 1921              NaN  /  0.811111  18.555556   4.722222  0.000000
#
#
#                            5         6
# Date       Degree days
# 2011-04-18 1127         0.25  1.583333
# 2011-05-25 1690          NaN       NaN
# 2011-06-08 1921          NaN       NaN

# %%
# Show significative differences
get_comparison_table_2011(data_mercia, data_rht3, num_leaves = range(1,7), by_leaf = True)
# Out:
#                 1      2      3      4      5      6
# datetime
# 2011-04-18  False  False  False  False  False  False
# 2011-05-25  False   True   True  False  False  False
# 2011-06-08  False   True  False  False  False  False

# %% [markdown]
# ## Plot statistical description by leaf

# %%
# Plot against date
compare_confidence_and_boxplot_mercia_rht3(data_mercia, data_rht3, weather, xaxis = 'degree_days', 
                                           leaves=range(1,5), xlims = [1600, 2000])

# %%
# Plot against age of leaf
compare_confidence_and_boxplot_mercia_rht3(data_mercia, data_rht3, weather, xaxis = 'age_leaf_lig', leaves=range(1,5), xlims = [350, 950])

# %% [markdown]
# ## Plot with weather and dates of ligulation of leaves

# %%
# All leaves plotted against date of ligulation flag leaf
compare_plot_with_weather_mercia_rht3(data_mercia, data_rht3, weather, 
                                      leaves = range(1, 5), xaxis = 'age_leaf_vs_flag_lig', 
                                      xlims = [-500, 700], error_bars = False)

# %%
compare_plot_with_weather_mercia_rht3(data_mercia, data_rht3, weather, 
                                      leaves = range(2, 3), xaxis = 'age_leaf_lig', 
                                      xlims = [0, 800], error_bars = True)

# %% [markdown]
# ## Whole season, whole plant comparison

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
wetness_duration_min = 10.
temp_min = 0.
temp_max = 25.
rht3_2011_winter = data_reader_2011('rht3_2011_winter.csv')
mercia_2011_winter = data_reader_2011('mercia_2011_winter.csv')

# %%
data_mercia, weather, adel_mercia = data_reader(year = 2011, variety = 'Mercia', from_file = 'control',
                                  wetness_duration_min = wetness_duration_min, temp_min = temp_min, temp_max = temp_max, hide_old_data = True)
data_rht3, weather, adel_rht3 = data_reader(year = 2011, variety = 'Rht3', from_file = 'control',
                                  wetness_duration_min = wetness_duration_min, temp_min = temp_min, temp_max = temp_max, hide_old_data = True)

# %%
data_m = pd.concat([mercia_2011_winter, data_mercia])
change_index(data_m, new_index = ['datetime', 'num_leaf_top'])

# %%
data_m = pd.concat([mercia_2011_winter, data_mercia])
#leaves = [1, 2, 9, 10, 11, 12]
change_index(data_m, new_index = ['datetime', 'num_leaf_top'])
df = plot_grouped_leaves(data_m, weather, variable='septo_green', degree_days=True, fig_size=(8,6), 
                            title_suffix=' tnt', ylims = [0, 20], title = 'mercia 2011: F10-12 winter; F1-2 spring', 
                            return_descriptor = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-7c2c9198346f> in <module>()
#       4 df = plot_grouped_leaves(data_m, weather, variable='septo_green', degree_days=True, fig_size=(8,6),
#       5                             title_suffix=' tnt', ylims = [0, 20], title = 'mercia 2011: F10-12 winter; F1-2 spring',
# ----> 6                             return_descriptor = True)
#
# d:\openaleapkg\echap\src\alinea\echap\disease\septo_data_treatment.py in plot_grouped_leaves(data, weather, variable, degree_days, alpha, fig_size, title_suffix, ylims, title, return_descriptor, comparison_table, minimum_sample_size, ax, fixed_color, marker, linestyle, filling_contour, display_box)
#     415     # Format DataFrame to get mean and standard error
#     416     df_mean = get_mean(data, column=variable, by_leaf=False, xaxis = 'datetime')
# --> 417     df_low, df_high = get_confidence_interval(data, weather, column=variable, by_leaf=False)
#     418
#     419     if return_descriptor == True:
#
# d:\openaleapkg\echap\src\alinea\echap\disease\septo_data_treatment.py in get_confidence_interval(df, weather, column, by_leaf, xaxis, add_ddays)
#     204     df_count = table_count_notations(df, weather, variable = column, xaxis = xaxis, add_ddays = add_ddays)
#     205     if any(x<20 for x in df_count.values.flat if x!='-' and not np.isnan(x)):
# --> 206         df_low_high = get_bootstrap_error_margin(df, column=column, xaxis = xaxis, by_leaf = by_leaf)
#     207         if not by_leaf:
#     208             df_low_high = pd.DataFrame(df_low_high, xaxis = 'datetime')
#
# d:\openaleapkg\echap\src\alinea\echap\disease\septo_data_treatment.py in get_bootstrap_error_margin(df, column, xaxis, by_leaf, from_top)
#     190             return pd.concat(dfs, axis = 1)
#     191     else:
# --> 192         df_ = df_.groupby(level=[0]).apply(lambda x: bootstr(x[~np.isnan(x)]))
#     193         return df_
#     194
#
# C:\Python27\lib\site-packages\pandas\core\groupby.pyc in apply(self, func, *args, **kwargs)
#     635             return func(g, *args, **kwargs)
#     636
# --> 637         return self._python_apply_general(f)
#     638
#     639     def _python_apply_general(self, f):
#
# C:\Python27\lib\site-packages\pandas\core\groupby.pyc in _python_apply_general(self, f)
#     639     def _python_apply_general(self, f):
#     640         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 641                                                    self.axis)
#     642
#     643         return self._wrap_applied_output(keys, values,
#
# C:\Python27\lib\site-packages\pandas\core\groupby.pyc in apply(self, f, data, axis)
#    1236             # group might be modified
#    1237             group_axes = _get_axes(group)
# -> 1238             res = f(group)
#    1239             if not _is_indexed_like(res, group_axes):
#    1240                 mutated = True
#
# C:\Python27\lib\site-packages\pandas\core\groupby.pyc in f(g)
#     633         @wraps(func)
#     634         def f(g):
# --> 635             return func(g, *args, **kwargs)
#     636
#     637         return self._python_apply_general(f)
#
# d:\openaleapkg\echap\src\alinea\echap\disease\septo_data_treatment.py in <lambda>(x)
#     190             return pd.concat(dfs, axis = 1)
#     191     else:
# --> 192         df_ = df_.groupby(level=[0]).apply(lambda x: bootstr(x[~np.isnan(x)]))
#     193         return df_
#     194
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#data = pd.concat([rht3_2011_winter, data_rht3])
data_r = pd.concat([rht3_2011_winter, data_rht3[data_rht3['num_leaf_top']<=3]])
#leaves = [1, 2, 9, 10, 11, 12]

df = plot_grouped_leaves(data_r, weather, variable='septo_green', degree_days=True, fig_size=(8,6), 
                            title_suffix=' tnt', ylims = [0, 20], title = 'mercia 2011: F10-12 winter; F1-2 spring', 
                            return_descriptor = True, fixed_color = 'r')

# %%
fig, ax = plt.subplots(figsize = (8,6))
df_r = plot_grouped_leaves(data_r, weather, variable='septo_green', degree_days=True, fig_size=(8,6), 
                            title_suffix=' tnt', ylims = [0, 20], title = '', 
                            return_descriptor = True, fixed_color = 'r', ax = ax)
df_r.to_csv('mean_severity_rht3_2011.csv', sep=';')
df_m = plot_grouped_leaves(data_m, weather, variable='septo_green', degree_days=True, fig_size=(8,6), 
                            title_suffix=' tnt', ylims = [0, 20], title = 'F10-12 winter; F1-2-3 spring', 
                            return_descriptor = True, fixed_color = 'g', ax = ax)
df_m.to_csv('mean_severity_mercia_2011.csv', sep=';')

labels = ['Mean', 'Confidence\n interval \n', 'Rht3', 'Mercia']
proxys = [plt.Line2D((0,1),(0,0), color='k', marker='o', linestyle='-'),
          plt.Rectangle((0,0), 0,0, facecolor='k', alpha = 0.3),
          plt.Rectangle((0,0), 0,0, facecolor='r', alpha = 0.3),
          plt.Rectangle((0,0), 0,0, facecolor='g', alpha = 0.3)]
ax.legend(proxys, labels, bbox_to_anchor=(1.02, 0.5), loc=2, borderaxespad=0.)
savefig('rht3_vs_mercia_2011.png', bbox_inches='tight')
