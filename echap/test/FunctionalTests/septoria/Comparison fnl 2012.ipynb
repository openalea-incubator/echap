# %% [markdown]
# # Compare septoria data on Tremie wheat from Grignon 2012 between plants with varied final leaf numbers (FNL)

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
pd.options.display.max_columns = 50
data, weather = data_reader(year = 2012, variety = 'Tremie12', from_file = 'control')
#data, weather = data_reader(year = 2012, variety = 'Tremie12', from_file = 'reference')
data_grouped = group_by_fnl(data)

# %% [markdown]
# ## Contingency

# %%
# Number of samples by FNL for septoria on green
compare_contingency_by_fnl(data, weather, variable = 'septo_green')
# Out:
#                        FNL 12                 / FNL 13                      \
#                             1  2  3  4  5  6  /      1   2   3   4   5   6
# Date       Degree days
# 2012-04-03 1167             -  -  -  6  5  4  /      -   -   -   -  17  23
# 2012-04-11 1237             -  -  6  6  5  -  /      -   -  10  22  24  23
# 2012-04-26 1351             -  6  6  6  5  -  /      -  12  24  24  24  18
# 2012-05-03 1435             6  6  6  6  4  -  /     11  24  24  24  23  14
# 2012-05-09 1512             6  6  6  6  2  -  /     22  24  24  23  19   9
# 2012-05-16 1608             6  6  6  2  -  -  /     22  23  24  20   5   1
# 2012-05-25 1736             6  6  6  -  -  -  /     22  23  24  12   -   -
# 2012-05-31 1848             6  6  -  -  -  -  /     21  23  16   -   -   -
# 2012-06-12 2029             5  -  -  -  -  -  /     20   6   -   -   -   -
#
#                                /
#                          7  8  /
# Date       Degree days
# ...

# %%
# Number of samples by FNL for septoria on green
compare_contingency_by_fnl(data, weather, variable = 'septo_green')
# Out:
#                        FNL 12                 / FNL 13                      \
#                             1  2  3  4  5  6  /      1   2   3   4   5   6
# Date       Degree days
# 2012-04-03 1167             -  -  -  6  5  4  /      -   -   -   -  17  23
# 2012-04-11 1237             -  -  6  6  5  -  /      -   -  10  22  24  23
# 2012-04-26 1351             -  6  6  6  5  -  /      -  12  24  24  24  18
# 2012-05-03 1435             6  6  6  6  4  -  /     11  24  24  24  23  14
# 2012-05-09 1512             6  6  6  6  2  -  /     22  24  24  23  19   9
# 2012-05-16 1608             6  6  6  2  -  -  /     22  23  24  20   5   1
# 2012-05-25 1736             6  6  6  -  -  -  /     22  23  24  12   -   -
# 2012-05-31 1848             6  6  -  -  -  -  /     21  23  16   -   -   -
# 2012-06-12 2029             5  -  -  -  -  -  /     20   6   -   -   -   -
#
#                                /
#                          7  8  /
# Date       Degree days
# ...

# %%
# Number of samples by FNL for severity
compare_contingency_by_fnl(data, weather, variable = 'severity')
# Out:
#                        FNL 12                 / FNL 13                      \
#                             1  2  3  4  5  6  /      1   2   3   4   5   6
# Date       Degree days
# 2012-04-03 1167             -  -  -  6  5  6  /      -   -   -   -  17  23
# 2012-04-11 1237             -  -  6  6  5  5  /      -   -  10  22  24  23
# 2012-04-26 1351             -  6  6  6  5  3  /      -  12  24  24  24  23
# 2012-05-03 1435             6  6  6  6  4  2  /     11  24  24  24  23  23
# 2012-05-09 1512             6  6  6  6  4  2  /     22  24  24  23  19  21
# 2012-05-16 1608             6  6  6  6  3  2  /     22  24  24  22  22  12
# 2012-05-25 1736             6  6  6  6  1  -  /     22  24  24  20  17   3
# 2012-05-31 1848             6  6  6  -  1  -  /     22  24  24  21   8   -
# 2012-06-12 2029             6  6  -  -  1  -  /     22  24  24   7   1   -
#
#                                /
#                          7  8  /
# Date       Degree days
# ...

# %% [markdown]
# ## Curves for individual samples by leaf layer

# %%
# Plot septoria on green on leaf 2 of all measured plants
plot_by_leaf_sample(data, weather, variable = 'septo_green', leaf = 2, xaxis = 'age_leaf')

# %%
# Plot septoria on green on leaf 2 of all measured plants grouped by fnl
plot_by_leaf_samples_by_fnl(data, weather, variable = 'severity', leaf = 5, xaxis = 'degree_days')

# %%
plot_by_leaf_sample(data, weather, variable = 'severity', leaf = 4, xaxis = 'age_leaf')

# %% [markdown]
# ## Mean by leaf and by FNL

# %%
# With initial grouping
plot_by_leaf_by_fnl(data, weather, variable='severity', xaxis = 'age_leaf', leaves = [3], 
                 fig_size=(8,6), title_suffix='_control', minimum_sample_size = 5, jumps = {11:0, 12:0, 13:0}, xlims = [-0, 1000])

# %%
plot_by_leaf_by_fnl(data, weather, variable='severity', xaxis = 'age_leaf', leaves = [4], 
                 fig_size=(8,6), title_suffix='_control', minimum_sample_size = 5, jumps = {11:0, 12:0, 13:0}, xlims = [-0, 1000])

# %%
warnings.filterwarnings('ignore')
plot_confidence_and_boxplot_by_fnl(data, weather, variable='severity', xaxis = 'age_leaf', leaves=range(1,7), fig_size=(15, 10), 
                                title_suffix='', minimum_sample_size = 0, xlims = [0, 950])

# %%
warnings.filterwarnings('ignore')
plot_confidence_and_boxplot_by_fnl(data, weather, variable='severity', xaxis = 'degree_days', leaves=range(1,7), fig_size=(15, 10), 
                                title_suffix='', minimum_sample_size = 0, xlims = [800, 2200])

# %%
plot_with_weather_by_fnl(data, weather, variable='severity', xaxis = 'degree_days', leaves = [5],
                        minimum_sample_size = 5, xlims = [600, 2200], fig_size = (15, 10))

# %%
plot_with_weather_by_fnl(data, weather, variable='severity', xaxis = 'degree_days', leaves = range(1,7),
                        minimum_sample_size = 5, xlims = [600, 2200], fig_size = (15, 10))

# %%
plot_with_weather_by_fnl(data, weather, variable='severity', xaxis = 'age_leaf_vs_flag_emg', leaves = range(1,7),
                        minimum_sample_size = 5, xlims = [-600, 800], fig_size = (15, 10))

# %% [markdown]
# ## Indicator of STB emergence: Date/Leaf age at 5% of disease curve

# %%
# Numbered from top
plot_mean_thr_date_by_leaf_by_fnl(data, weather, variable = 'severity', xaxis = 'degree_days', threshold = 2, 
                                  fit_function_name = None, error_method = error_margin_threshold)

# %%
# Numbered from bottom
plot_mean_thr_date_by_leaf_by_fnl(data, weather, variable = 'severity', xaxis = 'degree_days', 
                                  from_top = False, threshold = 50, fit_function_name = None, error_method = error_margin_threshold)

# %% [markdown]
# ## Indicator of STB colonization: Severity at given leaf age

# %%
plot_mean_value_at_age_by_leaf_by_fnl(data, weather, variable = 'severity', age = 400, fit_function_name = None, ylims = [0., 100.])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-bea3be9854eb> in <module>()
# ----> 1 plot_mean_value_at_age_by_leaf_by_fnl(data, weather, variable = 'severity', age = 400, fit_function_name = None, ylims = [0., 100.])
#
# d:\openaleapkg\echap\src\alinea\echap\disease\septo_data_treatment.pyc in plot_mean_value_at_age_by_leaf_by_fnl(data, weather, variable, age, fit_function_name, fig_size, add_mean, error_bars, error_method, ylims)
#    1435     for fnl, df in data_grouped.iteritems():
#    1436         df_value_at_age = get_value_at_age(df, weather, variable = variable,
# -> 1437                                             age = age, fit_function_name = fit_function_name)
#    1438         plot_mean_thr_date_by_leaf(df_value_at_age, ax = ax,
#    1439                                    color = next(colors), invert_xaxis = False,
#
# ...

# %% [markdown]
# ## Indicator of STB risk: count of risk events by leaf
