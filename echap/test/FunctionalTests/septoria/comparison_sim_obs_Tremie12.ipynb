# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
from alinea.echap.disease.alep_septo_evaluation import *
data_obs, weather = data_reader(year = 2012, variety = 'Tremie12', from_file = 'control')
data_sim = get_aggregated_data_sim(variety = 'Tremie12', nplants = 15, sporulating_fraction=5e-3, suffix='ref' )

# %%
plot_by_leaf(data_sim, weather, variable='severity', xaxis = 'age_leaf_vs_flag_emg', 
                 leaves = range(1,14), minimum_sample_size = 0, marker = '', error_bars = False)

# %%
plot_with_weather(data_obs, weather, leaves = range(1, 7), variable = 'severity', xaxis = 'age_leaf_vs_flag_emg', 
                  marker = 'd', xlims = [-1500, 1100], minimum_sample_size = 5)

# %%
plot_with_weather(data_sim, weather, leaves = range(1, 14), variable = 'severity', xaxis = 'age_leaf_vs_flag_emg', 
                  marker = '', xlims = [-1500, 1100], minimum_sample_size = 0)

# %%
plot_with_weather(data_obs, weather, leaves = range(1, 7), variable = 'severity', xaxis = 'degree_days', 
                  marker = 'd', xlims = [500, 2500], minimum_sample_size = 15)

# %%
plot_with_weather(data_sim, weather, leaves = range(1, 14), variable = 'severity', xaxis = 'degree_days', 
                  marker = '', xlims = [500, 2500], minimum_sample_size = 0)

# %%
plot_comparison_confidence_and_boxplot_sim_obs(data_obs, data_sim, weather, variable = 'severity',
                                               xaxis = 'age_leaf', xlims = [0, 1400])

# %%
plot_comparison_confidence_and_boxplot_sim_obs(data_obs, data_sim, weather, variable = 'severity',
                                               xaxis = 'degree_days', xlims = [1100, 2500])
# Out:
# C:\Python27\lib\site-packages\scikits.bootstrap-0.3.2-py2.7.egg\scikits\bootstrap\bootstrap.py:202: InstabilityWarning: Some values used top 10 low/high samples; results may be unstable.
# C:\Python27\lib\site-packages\scikits.bootstrap-0.3.2-py2.7.egg\scikits\bootstrap\bootstrap.py:202: InstabilityWarning: Some values used top 10 low/high samples; results may be unstable.
# C:\Python27\lib\site-packages\scikits.bootstrap-0.3.2-py2.7.egg\scikits\bootstrap\bootstrap.py:200: InstabilityWarning: Some values used extremal samples; results are probably unstable.
# C:\Python27\lib\site-packages\scikits.bootstrap-0.3.2-py2.7.egg\scikits\bootstrap\bootstrap.py:202: InstabilityWarning: Some values used top 10 low/high samples; results may be unstable.
