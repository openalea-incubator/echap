# %% [markdown]
# # Analysis of septoria measurements on Rht3 wheat from Grignon in 2011

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from pylab import savefig
from alinea.echap.disease.septo_data_reader import *
from alinea.echap.disease.septo_data_treatment import *
data, weather, adel = data_reader(year = 2011, variety = 'Rht3', from_file = 'control',
                                  wetness_duration_min = 10., temp_min = 0., temp_max = 25.,
                                  with_adel = True)

# %% [markdown]
# ## Contingency

# %%
# Count notations by leaf for septoria on green
tab = table_count_notations(data, weather, variable = 'septo_green')
save_table_to_latex(tab, 'count_notations/rht3_2011_ctrl_green.tex')
tab
# Out:
# Leaf number              1   2   3   4   5   6   7
# Date       Degree days
# 2011-04-18 1127          -   -   -   -  36  36  36
# 2011-05-25 1690         90  90  90  86   -   -   -
# 2011-06-08 1921         90  90  90  21   -   -   -

# %% [markdown]
# ## Curves for individual samples by leaf layer

# %%
# Plot septoria on green on leaf 1 of all measured plants
leaf = 3
plot_by_leaf_sample(data, weather, variable = 'septo_green', leaf = leaf, 
                    variety = 'Rht3', xaxis = 'degree_days', marker = '*', linestyle = '')
savefig('figures/rht3_2011_ctrl/samples_green_lf'+str(leaf)+'.png', bbox_inches='tight')

# %% [markdown]
# ## Mean by leaf

# %%
# Septoria on green
plot_by_leaf(data, weather, variable='septo_green', leaves = range(1,5), pointer=True, title_suffix='_control', 
             xaxis = 'age_leaf_vs_flag_lig', xlims = [350, 700])
savefig('figures/rht3_2011_ctrl/mean_by_leaf_green.png', bbox_inches='tight')

# %%
plot_by_leaf(data, weather, leaves = range(1,5),  variable='septo_green', pointer=True, title_suffix='_control', 
             xaxis = 'age_leaf_lig', xlims = [350, 900], error_bars = False)

# %% [markdown]
# ## Mean by leaf with weather

# %%
plot_with_weather(data, weather, leaves = range(1,5), variable='septo_green', xaxis = 'age_leaf_vs_flag_lig', 
                  xlims = [-400, 900], error_bars = True)

# %%
plot_with_weather(data, weather, leaves = range(2,3), variable='septo_green', xaxis = 'age_leaf_lig', xlims = [0, 800])

# %% [markdown]
# ## Statistical description for separate top leaves

# %%
# Get average confidence interval
df_mean, df_low, df_high = get_data_of_interest(data = data, weather = weather, 
                                                xaxis = 'degree_days', variable = 'septo_green', 
                                                leaves = range(1,5),
                                                minimum_sample_size = 0,
                                                error_bars = True)
df_int = (df_high - df_low)
df_int.mean().mean()
# Out:
# 4.9989761053471016

# %%
# Septoria on green with statistics by leaf
df_mean, df_high, df_low = plot_confidence_and_boxplot(data, weather, leaves = range(1,8), variable='septo_green', 
                                                       xaxis = 'age_leaf_lig', title_suffix='_control', xlims = [0, 1000], 
                                                       minimum_sample_size = 0)
savefig('figures/rht3_2011_ctrl/stat_green.png', bbox_inches='tight')

# %%
data_mercia, weather, adel = data_reader(year = 2011, variety = 'Mercia', from_file= 'control',
                                  wetness_duration_min = 10., temp_min = 0., temp_max = 25., 
                                  hide_old_data = True, with_adel = True)
data_rht3, weather, adel = data_reader(year = 2011, variety = 'Rht3', from_file= 'control',
                                  wetness_duration_min = 10., temp_min = 0., temp_max = 25., 
                                  hide_old_data = True, with_adel = True)
save_comparison_table_2011(data_mercia, data_rht3, weather, num_leaves = range(1,5))
# Out:
#                           Mercia                                 /      Rht3  \
#                                1         2          3         4  /         1
# Date       Degree days
# 2011-05-25 1690         0.179775  2.522222   5.710843  8.666667  /  0.844444
# 2011-06-08 1921         0.311111  9.493151  10.000000       NaN  /  0.820225
#
#
#                                 2      3     4
# Date       Degree days
# 2011-05-25 1690         11.298851  18.00  12.7
# 2011-06-08 1921         15.507937  16.25   NaN
